# %%
import numpy as np

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4a7adb2-f7d9-4868-bd5f-c125ba49b949" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4a7adb2-f7d9-4868-bd5f-c125ba49b949">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['House Price India.csv']))
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
x= df.drop('Postal Code',axis=1)
x.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Area of the basement  Built Year  \
# ...

# %%
y=df['Postal Code']
y
# Out:
# 0        122003
# 1        122004
# 2        122004
# 3        122005
# 4        122006
#           ...
# 14615    122066
# 14616    122072
# 14617    122056
# 14618    122042
# 14619    122018
# Name: Postal Code, Length: 14620, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest,ytrain,ytest = train_test_spilt(x,y,test size=0.2,random_state=12

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
xtrain
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 12389  6762822381  42686                   2                 1.50
# 5425   6762820755  42572                   5                 3.00
# 1287   6762829095  42511                   4                 2.75
# 13440  6762818332  42707                   3                 2.25
# 6988   6762812020  42595                   4                 2.50
# ...           ...    ...                 ...                  ...
# 7409   6762828093  42601                   5                 1.75
# 3325   6762825095  42543                   3                 1.00
# 9606   6762825937  42637                   4                 1.00
# 5787   6762818992  42576                   3                 1.00
# 14155  6762812739  42721                   5                 3.00
#
#        living area  lot area  number of floors  waterfront present  \
# 12389         1210      1278               2.0                   0
# ...

# %%
xtest
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 12149  6762815497  42683                   3                 1.00
# 13581  6762815303  42711                   3                 1.00
# 11595  6762826056  42671                   3                 1.00
# 2769   6762823995  42536                   3                 1.00
# 7393   6762824659  42601                   4                 2.50
# ...           ...    ...                 ...                  ...
# 7362   6762819318  42601                   4                 2.25
# 11132  6762822873  42664                   3                 1.75
# 142    6762824223  42494                   3                 3.00
# 1405   6762828140  42515                   3                 1.00
# 6184   6762817137  42582                   4                 1.75
#
#        living area  lot area  number of floors  waterfront present  \
# 12149         1210      3720               2.0                   0
# ...

# %%
ytrain
# Out:
# 12389    122007
# 5425     122014
# 1287     122023
# 13440    122026
# 6988     122027
#           ...
# 7409     122040
# 3325     122017
# 9606     122038
# 5787     122006
# 14155    122028
# Name: Postal Code, Length: 11696, dtype: int64

# %%
ytest
# Out:
# 12149    122047
# 13581    122028
# 11595    122023
# 2769     122064
# 7393     122053
#           ...
# 7362     122005
# 11132    122033
# 142      122022
# 1405     122034
# 6184     122031
# Name: Postal Code, Length: 2924, dtype: int64

# %%
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense

# %%
reg=Sequential()
reg.add(Dense(3,activation='relu'))
reg.add(Dense(45,activation='relu'))
reg.add(Dense(16,activation='relu'))
reg.add(Dense(4,activation='relu'))

# %%
reg.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
reg.fit(xtrain,ytrain,batch_size=10,epochs=25,validation_data=(xtest,ytest))
# Out:
# Epoch 1/25
# 1170/1170 [==============================] - 5s 3ms/step - loss: 25150722408448.0000 - mse: 25150722408448.0000 - val_loss: 14892055552.0000 - val_mse: 14892055552.0000
# Epoch 2/25
# 1170/1170 [==============================] - 3s 2ms/step - loss: 14892079104.0000 - mse: 14892079104.0000 - val_loss: 14892055552.0000 - val_mse: 14892055552.0000
# Epoch 3/25
# 1170/1170 [==============================] - 3s 2ms/step - loss: 14892076032.0000 - mse: 14892076032.0000 - val_loss: 14892055552.0000 - val_mse: 14892055552.0000
# Epoch 4/25
# 1170/1170 [==============================] - 3s 2ms/step - loss: 14892069888.0000 - mse: 14892069888.0000 - val_loss: 14892055552.0000 - val_mse: 14892055552.0000
# Epoch 5/25
# 1170/1170 [==============================] - 3s 3ms/step - loss: 14892057600.0000 - mse: 14892057600.0000 - val_loss: 14892055552.0000 - val_mse: 14892055552.0000
# Epoch 6/25
# ...

# %%
reg.predict([[123123,345345,2344324,2]])
# Out:
# 1/1 [==============================] - 0s 163ms/step
# array([[0., 0., 0., 0.]], dtype=float32)
